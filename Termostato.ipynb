# %%
def agente_termostato(temperatura_actual, temperatura_objetivo=22, margen=1.0):
    """
    Percepción (S):La temperatura actual
    Acciones (A):encerder_airecondicionado , encender_calefaccion el sistema
    Entorno (E): Habitacion cerrada
    Medida de desempeño (P): Tiempo de optimizacion de la termperatura , ahorro energetico 
    """
    diferencia = temperatura_actual - temperatura_objetivo
    if diferencia > margen:
    return "enciendo_aireacondicionado"
    elif diferencia < -margen:
    return "enciendo_calefaccion"
    else:
    return "apagar el sistema"
# Out:
#   Cell In[2], line 10
#     return "enciendo_aireacondicionado"
#     ^
# IndentationError: expected an indented block after 'if' statement on line 9
